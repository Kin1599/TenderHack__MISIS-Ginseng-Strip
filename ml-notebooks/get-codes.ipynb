# %%
import numpy as np
import pandas as pd

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/tender-hack-dataset/odkp.csv
# /kaggle/input/tender-hack-dataset/TenderHack_msk.xlsx
# /kaggle/input/tender-hack-dataset/all_manufacturers.txt
# /kaggle/input/tender-hack-dataset/TenderHack_msk.csv
# /kaggle/input/tender-hack-dataset/all_models.txt
# /kaggle/input/tender-hack-dataset/products_by_1000
# /kaggle/input/tender-hack-dataset/top_10_char_ru.csv
# /kaggle/input/tender-hack-dataset/kgpz.csv
# /kaggle/input/tender-hack-dataset/tender-names/tender-names/work_names
# /kaggle/input/tender-hack-dataset/tender-names/tender-names/uslugi_names
# /kaggle/input/tender-hack-dataset/tender-names/tender-names/products_names

# %%
kgpz = pd.read_csv('/kaggle/input/tender-hack-dataset/kgpz.csv', sep=';')

# %%
kgpz = kgpz.applymap(lambda x: x.lower() if isinstance(x, str) else x)
# Out:
# /tmp/ipykernel_33/4121573896.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   kgpz = kgpz.applymap(lambda x: x.lower() if isinstance(x, str) else x)

# %%
kgpz
# Out:
#                    kpgzCode  \
# 0                  код кпгз
# 1            01.02.09.01.09
# 2            01.02.09.01.13
# 3            01.02.09.03.07
# 4            01.02.09.04.04
# ...                     ...
# 17527     01.02.10.11.01.35
# 17528     01.11.02.01.08.04
# 17529  01.02.10.43.01.15.03
# 17530  01.02.10.43.01.15.02
# 17531  01.02.10.43.01.15.01
#
#                                                 kpgzName   global_id  \
# 0                                      наименование кпгз   global_id
# 1      препараты, способствующие пищеварению (включая...   638861809
# 2                         общетонизирующие препараты,a13   638861811
# 3                              бета-адреноблокаторы, c07   638861815
# 4      препараты для лечения зуда (включая антигистам...   638861817
# ...                                                  ...         ...
# 17527  рукоятка ультразвуковой хирургической системы ...  2449291767
# ...

# %%
odkp = pd.read_csv('/kaggle/input/tender-hack-dataset/odkp.csv', sep=';')

# %%
odkp
# Out:
#                                                     Name             Idx  \
# 0                                           наименование          индекс
# 1                                       услуги библиотек      r.91.01.11
# 2                                       услуги библиотек  r.91.01.11.000
# 3                                         услуги архивов      r.91.01.12
# 4                                         услуги архивов  r.91.01.12.000
# ...                                                  ...             ...
# 20169                     ленты из кремнеземного волокна  c.23.14.11.111
# 20170                        ленты из кварцевого волокна  c.23.14.11.112
# 20171                     машины трамбовочные самоходные  c.28.92.24.111
# 20172  технические средства разравнивания и уплотнени...  c.28.92.24.112
# 20173  машины трамбовочные самоходные и технические с...  c.28.92.24.119
#
#             Razdel           Kod  \
# 0      код раздела           код
# ...

# %%
def get_codes(cat):
    s_cat = cat.lower()
    codes_odkp = odkp.loc[odkp['Name'] == s_cat]['Kod'].tolist()
    codes_kgpz = kgpz.loc[kgpz['kpgzName'] == s_cat]['kpgzCode'].tolist()
    
    return (codes_odkp, codes_kgpz)

# %%
get_codes('Бумага для офисной техники')
# Out:
# ([], ['01.15.01.01.01'])
