# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/kaggle/input/tender-hack-dataset/top_10_char_ru.csv', sep=',')

# %%
data = []

# %%
for x in df['Category_ID']:
    category_id, category_name, top_10_char = x.split(',')[0], x.split(',')[1], x.split(',')[2:]
    data.append((category_id, category_name, top_10_char))

# %%
df_char = pd.DataFrame(data=data, columns=df.columns)

# %%
df_char
# Out:
#      Category_ID                                      Category_Name  \
# 0        1100077                                  Конверты почтовые
# 1        1100142                                Наградная продукция
# 2        1103245                                            Конфеты
# 3        1103367                                Зеркала интерьерные
# 4        1116434                   Смеси сухие белковые композитные
# ...          ...                                                ...
# 7355   793410082        ФУТЛЯР-УКЛАДКИ/УКЛАДКИ И МЕДИЦИНСКИЕ НАБОРЫ
# 7356   793410084                           КАТЕТЕРЫ ДЛЯ ГЕМОДИАЛИЗА
# 7357   793410086                        ФИЛЬТРЫ ДЛЯ СИСТЕМЫ АФЕРЕЗА
# 7358   793410088  ГЕМОСОРБЕНТЫ СЕЛЕКТИВНЫЕ ДЛЯ УДАЛЕНИЯ ЭНДОТОКС...
# 7359   793410090              МАТЕРИАЛЫ ДЛЯ КОРРЕКЦИИ ДЕФЕКТОВ КОЖИ
#
#                                             top_10_char
# 0     ["['окно',  'защита от попыток незаметного вск...
# 1     ["['размер изделия',  'количество в упаковке',...
# 2     ["['соответствует требованиям госта',  'ширина...
# 3     ["['ширина',  'форма полотна',  'высота',  'дл...
# 4     ["['объем',  'пищевые волокна',  'осмолярность...
# ...                                                 ...
# 7355  ["['бинт марлевый медицинский стерильный 5 м х...
# 7356  ["['диаметр катетера',  'диаметр',  'расширите...
# 7357  ["['масса',  'стерильность',  'принцип действи...
# 7358  ["['объем заполнения кровью',  'сорбционная ем...
# 7359  ["['объем',  'ширина',  'длина',  'количество ...
#
# [7360 rows x 3 columns]

# %%
df_char.to_csv('chars_top_10.csv')

# %%
df_char = pd.read_csv('/kaggle/working/chars_top_10.csv')
df_char = df_char.drop('Unnamed: 0', axis=1)

# %%
df_char
# Out:
#       Category_ID                                      Category_Name  \
# 0         1100077                                  Конверты почтовые
# 1         1100142                                Наградная продукция
# 2         1103245                                            Конфеты
# 3         1103367                                Зеркала интерьерные
# 4         1116434                   Смеси сухие белковые композитные
# ...           ...                                                ...
# 7355    793410082        ФУТЛЯР-УКЛАДКИ/УКЛАДКИ И МЕДИЦИНСКИЕ НАБОРЫ
# 7356    793410084                           КАТЕТЕРЫ ДЛЯ ГЕМОДИАЛИЗА
# 7357    793410086                        ФИЛЬТРЫ ДЛЯ СИСТЕМЫ АФЕРЕЗА
# 7358    793410088  ГЕМОСОРБЕНТЫ СЕЛЕКТИВНЫЕ ДЛЯ УДАЛЕНИЯ ЭНДОТОКС...
# 7359    793410090              МАТЕРИАЛЫ ДЛЯ КОРРЕКЦИИ ДЕФЕКТОВ КОЖИ
#
#                                             top_10_char
# 0     ['"[\'окно\'', " 'защита от попыток незаметног...
# 1     ['"[\'размер изделия\'', " 'количество в упако...
# 2     ['"[\'соответствует требованиям госта\'', " 'ш...
# 3     ['"[\'ширина\'', " 'форма полотна'", " 'высота...
# 4     ['"[\'объем\'', " 'пищевые волокна'", " 'осмол...
# ...                                                 ...
# 7355  ['"[\'бинт марлевый медицинский стерильный 5 м...
# 7356  ['"[\'диаметр катетера\'', " 'диаметр'", " 'ра...
# 7357  ['"[\'масса\'', " 'стерильность'", " 'принцип ...
# 7358  ['"[\'объем заполнения кровью\'', " 'сорбционн...
# 7359  ['"[\'объем\'', " 'ширина'", " 'длина'", " 'ко...
#
# [7360 rows x 3 columns]

# %%
import re

def remove_quotes_and_special_chars(text):
    pattern = r'[\'\"!@#$%^&*()_+={}\[\]:;<>.?\/\\|`~—–−-]'
    cleaned_text = re.sub(pattern, '', text)
    return cleaned_text

# %%
def get_fields(cat_name):
    s = df_char[df_char['Category_Name'] == cat_name]
    return remove_quotes_and_special_chars(s['top_10_char'].tolist()[0]).split(',  ')

# %%
get_fields('КАТЕТЕРЫ ДЛЯ ГЕМОДИАЛИЗА')
# Out:
# ['диаметр катетера',
#  'диаметр',
#  'расширитель',
#  'в наборе',
#  'имплантируемая длина',
#  'размер катетера',
#  'длина катетера',
#  'материал катетера',
#  'срок годности на момент поставки',
#  'зажимы на портах']
